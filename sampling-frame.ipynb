# %%
HIVE_SNAPSHOT = "2018-01"
END_OF_DATA = "2018-02-01 00:00:00"
DAYS_IN_LAST_3_MO = 92

# %%
frame_query = """
-- TABLE OF
with mo_edits as (
    select
        event_user_text as user,
        year(event_timestamp) as year,
        month(event_timestamp) as month,
        sum(if(wiki_db = "wikidatawiki", 0.1, 1)) as edits
    from wmf.mediawiki_history
    where
        -- REGISTERED
        event_user_is_anonymous = false and
        
        -- NON-BOT
        event_user_is_bot_by_name = false and
        not array_contains(event_user_groups, "bot") and
        
        -- CONTENT
        page_namespace_is_content_historical = true and
        
        -- EDITS
        event_entity = "revision" and
        event_type = "create" and
        
        -- FROM THE LAST 3 MONTHS
        unix_timestamp(event_timestamp, "yyyy-MM-dd HH:mm:ss.0") 
            > (unix_timestamp("{end_of_data}") - (60 * 60 * 24 * {days_in_last_3_mo})) and

        -- FROM THE LATEST SNAPSHOT
        snapshot = "{hive_snapshot}"    
    -- PER USER, PER MONTH
    group by event_user_text, year(event_timestamp), month(event_timestamp)
), 

-- TABLE OF
yr_wiki_edits as (
    select
        event_user_text as user,
        wiki_db as wiki,
        sum(if(wiki_db = "wikidatawiki", 0.1, 1)) as edits,
        max(event_timestamp) as latest_edit
    from wmf.mediawiki_history
    where
        -- REGISTERED
        event_user_is_anonymous = false and
        
        -- NON-BOT
        event_user_is_bot_by_name = false and
        not array_contains(event_user_groups, "bot") and
        
        -- EDITS
        event_entity = "revision" and
        event_type = "create" and
        
        -- FROM THE LAST YEAR
        unix_timestamp(event_timestamp, "yyyy-MM-dd HH:mm:ss.0") 
            > (unix_timestamp("{end_of_data}") - (60 * 60 * 24 * 365)) and
        
        -- FROM THE LATEST SNAPSHOT
        snapshot = "{hive_snapshot}"
    
    -- PER USER, PER WIKI
    group by event_user_text, wiki_db
)

-- FINAL SELECT OF
select 
    recent_actives.user as user,
    wikis_ranked.wiki as home_wiki,
    global_edits,
    coalesce(yr_edits.enwiki_edits, 0) as enwiki_edits,
    active_months

-- USERS ACTIVE IN 2 OF 3 MONTHS
from (
    select
        user,
        sum(if(edits >= 5, 1, 0)) as active_months
    from mo_edits
    where
        -- WHO ARE NOT WMF STAFF
        user not like "%WMF%"
    group by user
    having active_months >= 2
) recent_actives

-- JOINED TO THEIR HOME WIKI
left join (
    select
        user,
        wiki,
        -- in the unlikely event that wikis are tied by edit count and latest edit, 
        -- row_number() will break it somehow
        row_number() over (partition by user order by edits desc, latest_edit desc) as rank
    from yr_wiki_edits
) wikis_ranked
on 
    recent_actives.user = wikis_ranked.user and
    rank = 1

-- JOINED TO THEIR GLOBAL AND ENWIKI EDIT COUNTS
left join (
    select
    user,
    sum(edits) as global_edits,
    sum(if(wiki = "enwiki", edits, 0)) as enwiki_edits
    from yr_wiki_edits
    group by user
)  yr_edits
on 
    recent_actives.user = yr_edits.user
"""

# %%
frame = run_hive(
    frame_query.format(
        hive_snapshot = HIVE_SNAPSHOT,
        end_of_data = END_OF_DATA,
        days_in_last_3_mo = DAYS_IN_LAST_3_MO
    )
)

# %%
frame
# Out:
#                       user     home_wiki  global_edits  enwiki_edits  \
# 0               ! Bikkit !        dewiki         559.2           1.0
# 1             !NewLondon31        jawiki          46.0           1.0
# 2                  !Silent        ptwiki       22349.8           2.0
# 3      "Colorado Campeão"!        ptwiki         422.0           4.0
# 4        "quasi" tuttologo        itwiki         115.0           1.0
# 5                 $andlo17        itwiki          79.0           0.0
# 6               $uperFan32        enwiki        2627.0        2627.0
# 7                   %Pier%        itwiki        3315.3           0.0
# 8               &beer&love  wikidatawiki       19484.3           1.0
# 9                   'Inyan        frwiki        2108.4           2.0
# 10              (:Julien:)        frwiki        3571.6          31.0
# 11       (U+262D) lâm minh        zhwiki         424.5           2.0
# 12                  (dwt).   commonswiki         782.0           0.0
# 13                   (ios)        dewiki          58.0           0.0
# 14              **Romina**  eswikisource        1073.0           0.0
# 15                   *SGR*        dewiki        1863.9          21.0
# 16                 *Treker        enwiki       26210.3       26088.0
# 17               *Youngjin        kowiki        1220.3          46.0
# 18                 *angys*        zhwiki       17014.3        2778.0
# 19               *feridiák        huwiki        3796.0           0.0
# 20                  *j*jac  frwikisource       10481.3           0.0
# 21             *thing goes        dewiki         623.7         129.0
# 22                 - Luc -        frwiki        1126.4           3.0
# 23                -- -- --        enwiki        1063.8         937.0
# 24            -A-M-B-1996-        enwiki         206.0         171.0
# 25               -A-MARCUS        enwiki          56.0          56.0
# 26                 -Lemmy-        enwiki        1221.3         676.0
# 27                 -Ondri-        enwiki          41.0          24.0
# 28               -PhoeniX-        ruwiki         506.0           0.0
# 29                -Rose05-        frwiki          72.0           3.0
# ...                    ...           ...           ...           ...
# 52466             충북선 무궁화호        kowiki         317.1           0.0
# 52467                칼빈500        kowiki       13890.1         747.0
# 52468                   커뷰        kowiki       16140.6           1.0
# 52469                  쿠모야        kowiki        1734.6          34.0
# 52470                  크로키        kowiki         295.0           0.0
# 52471                 크리스탈        kowiki        1863.5           0.0
# 52472                  키위짱        kowiki         158.0           0.0
# 52473                 키키카카        kowiki        1794.0           0.0
# 52474                   탑봇        kowiki         122.0           0.0
# 52475                   태왕        kowiki          59.0           1.0
# 52476                 태현 정        kowiki         734.7           9.0
# 52477                  테리정        kowiki        3926.1           0.0
# 52478                   퇴출        kowiki         214.4           0.0
# 52479                 하내탕롱  kowiktionary         156.0           0.0
# 52480                   한림        kowiki         392.1           0.0
# 52481                  한민족        kowiki          84.5           0.0
# 52482                해적사냥꾼        kowiki         248.0           0.0
# 52483                 환난상구        kowiki        1410.0           6.0
# 52484               황미영남준우        kowiki         419.0           0.0
# 52485                 황제숙종        kowiki        1129.3           6.0
# 52486                （董宗瑋）        zhwiki         837.5           0.0
# 52487              Ｂｕｒｎｉｎｇ        jawiki          30.0           0.0
# 52488                 ＤＢ35        jawiki          92.0           0.0
# 52489              ＤＦ．Ｋｉｎｇ        jawiki          73.0           0.0
# 52490           ＫＥＮＺＯ62118        jawiki          59.0           0.0
# 52491       Ｋｅｎｓａｎ１９７２１２２４        jawiki         568.0           0.0
# 52492                  ＫｏＺ        jawiki        4883.2           4.0
# 52493               ＲＩＥＡＫＩ        jawiki          77.0           0.0
# 52494            Ｓ20400343        jawiki         106.0           0.0
# 52495                 ＴＧＫＴ        jawiki          53.0           0.0
#
#        active_months
# 0                  3
# 1                  2
# 2                  3
# 3                  3
# 4                  3
# 5                  2
# 6                  3
# 7                  3
# 8                  3
# 9                  3
# 10                 3
# 11                 2
# 12                 2
# 13                 2
# 14                 3
# 15                 3
# 16                 3
# 17                 3
# 18                 3
# 19                 3
# 20                 3
# 21                 3
# 22                 3
# 23                 3
# 24                 3
# 25                 2
# 26                 3
# 27                 2
# 28                 2
# 29                 2
# ...              ...
# 52466              2
# 52467              3
# 52468              3
# 52469              3
# 52470              2
# 52471              3
# 52472              3
# 52473              3
# 52474              3
# 52475              3
# 52476              3
# 52477              3
# 52478              3
# 52479              2
# 52480              2
# 52481              2
# 52482              3
# 52483              3
# 52484              3
# 52485              3
# 52486              2
# 52487              2
# 52488              2
# 52489              2
# 52490              2
# 52491              3
# 52492              3
# 52493              2
# 52494              2
# 52495              2
#
# [52496 rows x 5 columns]

# %%
# Check for duplicate users
frame.user.nunique()
# Out:
# 52496

# %%
# 10 random users to check against [an edit counter](https://xtools.wmflabs.org/ec)
frame.sample(n = 10)
# Out:
#                       user home_wiki  global_edits  enwiki_edits  \
# 12184         Durandal2010    jawiki          82.0           0.0
# 50645           محمد جبيرة    frwiki          20.0           6.0
# 37720           Rolf Ulmer    dewiki          26.0           0.0
# 22611       JuninhoTotal90    ptwiki         473.0           0.0
# 43006          Teddyktchan    zhwiki          27.0           5.0
# 19903            Interfase    ruwiki        7367.1          78.0
# 8396            ChrisTakey    enwiki         133.0         133.0
# 20109       It's Wiki Time    enwiki         182.0         178.0
# 39318  Scottandrewhutchins    enwiki         175.0         174.0
# 4621                B14709    enwiki         691.0         685.0
#
#        active_months
# 12184              2
# 50645              2
# 37720              2
# 22611              3
# 43006              3
# 19903              3
# 8396               3
# 20109              2
# 39318              2
# 4621               3

# %%
# Those 10 users check out, let's write the frame to a TSV!
frame.to_csv("./sampling-frame.tsv", sep = "\t", index = False)
